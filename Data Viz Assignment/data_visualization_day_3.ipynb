# %% [markdown]
# ##### import tips dataset.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('tips.csv')
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ##### 1. Write a Python program to display a bar chart of the total bill of Gender and write the intuition about the plot.

# %%
### code here
sns.barplot(x=df.sex,y=df.total_bill)
plt.show()

# Male gives the more tips than female.

# %% [markdown]
# ###### 2. Write a Python program to display a box plot of the total bill of day and hue = "smoker" and write the intuition about the plot.

# %%
#### code here
sns.boxplot(x=df.day,y=df.total_bill,hue=df.smoker)
plt.show()

# Persons doing smoking pay more bill as compared to non-smoker.

# %% [markdown]
# ##### 3. Write a Python program to display a violin plot of the total bill of Day and hue = "sex" and write the intuition about the plot.

# %%
### code here
sns.violinplot(x=df.day,y=df.total_bill,hue=df.sex)
plt.show()

# Male pays more bill than female

# %% [markdown]
# ##### 4. Write a Python program to display a strip plot of the total bill of Day and hue = "sex" and write the intuition about the plot.

# %%
### code here 
sns.stripplot(x=df.day,y=df.total_bill,hue=df.sex)
plt.show()

# %% [markdown]
# ##### 5. Write a Python program to display heat map of dataframe and write the intuition about the plot.

# %%
### code here
sns.heatmap(data=df.corr(),annot=True)
plt.show()

# %% [markdown]
# ##### 6. Write a Python program to display scatter plot of total bill of tip and write the intuition about the plot.

# %%
### code here
sns.scatterplot(x=df.tip,y=df.total_bill)
plt.show()

# %% [markdown]
# ##### 7. Write a Python program to display density plot of all numerical columns from the dataframe and write the intution about plot.

# %%
### code here
plt.figure(figsize=(15,5))
plt.subplot(1,3,1)
sns.kdeplot(x='total_bill', data=df)
plt.subplot(1,3,2)
sns.kdeplot(x='tip', data=df)
plt.subplot(1,3,3)
sns.kdeplot(x='size', data=df)
plt.show()

# %% [markdown]
# ##### 8. Write a Python program to calculate average total bills by days and display top 4 days by plot.

# %%
### code here
df1=pd.pivot_table(values='total_bill',columns='day',data=df,aggfunc='mean').T
df1.reindex(df1['total_bill'].sort_values(ascending=False).index)
# Out:
#       total_bill
# day
# Sun    21.410000
# Sat    20.441379
# Thur   17.682742
# Fri    17.151579

# %%
df1.reindex(df1['total_bill'].sort_values(ascending=False).index).plot(kind='bar')
plt.show()

# %% [markdown]
# #### Bonus Question

# %% [markdown]
# ###### 1. What is Histogram chart ?

# %%
#### write here
- A histogram is a chart that groups numeric data into bins, displaying the bins as segmented columns. 
- They are used to depict the distribution of a dataset: how often values fall into ranges.

# %% [markdown]
# ##### 2. What is box plot ?

# %%
### write here
- A box plot is a type of chart often used in explanatory data analysis. 
- Box plots visually show the distribution of numerical data and skewness through displaying the data quartiles (or percentiles) and averages.

# %% [markdown]
# ##### 3. What are the plots we can use for univeriate analysis.

# %%
### write here
1. Count plot
2. Swarm plot
3. Strip plot
4. Density plot
5. Box plot
6. Violin plot
7. Histogram

# %% [markdown]
# ##### 4. What are the plots we can use for bivariate analysis.

# %%
### code here
1. Scatter plot
2. Line plot
3. Bar plot
4. Box plot
5. Violin plot
6. Strip plot
7. Reg plot
8. Cat plot

# %% [markdown]
# ###### 5. What are plot we can use for multivariate analysis.

# %%
### code here
1. Pair plot
2. Heat Map
